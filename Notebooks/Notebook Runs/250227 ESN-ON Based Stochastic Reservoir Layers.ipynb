# %% [markdown]
# <!-- # Setup -->

# %% [markdown]
# ## Libraries

# %%
using DelimitedFiles

# %%
include("../Scripts/EchoStateNetworks.jl")
using .EchoStateNetworks
include("../Scripts/ONReservoir.jl")
using .ONReservoir
include("../Scripts/TurningError.jl")
using .TurningError
include("../Scripts/TestingFunctions.jl")
using .TestingFunctions

# %% [markdown]
# ## Read in Lorenz testing data

# %%
lo_train = vec(readdlm("../Data/lorenz_train.txt"))
lo_test = vec(readdlm("../Data/lorenz_test.txt"));

# %% [markdown]
# ## Testing parameters

# %%
testing_params = create_testing_params(
    stochastic=true,
    stochastic_rescale_V_rec=true
);

# %% [markdown]
# # Multi step predictions

# %%
test_multi_step(lo_train, lo_test, 3, 100; n_steps=20, from=500, to=1000, ignore_first=100, testing_params=testing_params)
# Out:
# Created reservoir of size: (600,)
# Created reservoir of size: (600,)
# Overall RMSE:
#     Vanilla: 3.9217170280439184
#     Ordinal network reservoir: 2.954229933286366
# Turning partition RMSE:
#     Vanilla: 4.524969301341727
#     Ordinal network reservoir: 3.7255789688767984

# %%
test_multi_step(lo_train, lo_test, 3, 100; n_steps=1, from=500, to=1000, ignore_first=100, testing_params=testing_params)
# Out:
# Created reservoir of size: (600,)
# Created reservoir of size: (600,)
# Overall RMSE:
#     Vanilla: 0.4943358846088388
#     Ordinal network reservoir: 0.7566206075268576
# Turning partition RMSE:
#     Vanilla: 0.12103037196565485
#     Ordinal network reservoir: 3.1620386159694998

# %% [markdown]
# # Multi step predictions - multi trial RMSE calculation

# %%
graph_multi_step_RMSE_vs_n_steps(lo_train, lo_test, [1, 2, 3, 5, 10, 20, 30, 40, 50, 70, 100], 3, 50; ignore_first=100, trials=30,
    testing_params=testing_params)

# %%
graph_multi_step_RMSE_vs_n_steps(lo_train, lo_test, [1, 2, 3, 5, 10, 20, 30, 40, 50, 70, 100], 3, 50; ignore_first=100, trials=30)
