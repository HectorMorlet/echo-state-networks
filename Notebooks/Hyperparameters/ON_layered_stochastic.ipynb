# %%
using JSON
using CairoMakie

include("../../Modules/TestingFunctions.jl")
using .TestingFunctions
# Out:
# WARNING: replacing module TestingFunctions.
# WARNING: using TestingFunctions.find_test in module Main conflicts with an existing identifier.
# WARNING: using TestingFunctions.chart_tests in module Main conflicts with an existing identifier.

# %% [markdown]
# # Testing number of steps

# %%
ON_layered_test_search = Dict(
    "prediction_type" => "multi_step",
    "testing_params" => Dict(
        "mask_states_b4_readout" => false,
        "stochastic" => true,
        "stochastic_rescale_V_rec" => true,
        "readout_switching" => false
    ),
    "data" => "Lorenz 0_01",
    "testing_parameter" => "n_steps",
    "ignore_first" => 100,
    "trials" => 30,
    "total_k" => 468
)
ON_layered_tests = find_test(ON_layered_test_search)
# Out:
# 4-element Vector{Any}:
#  Dict{String, Any}("prediction_type" => "multi_step", "testing_params" => Dict{String, Any}("stochastic" => true, "mask_states_b4_readout" => false, "stochastic_rescale_V_rec" => true, "readout_switching" => false), "data" => "Lorenz 0_01", "num_partitions" => 1, "error_funcs" => Any["RMSE", "turning_partition_RMSE"], "testing_parameter" => "n_steps", "k" => 468, "date" => "2025-03-10", "ignore_first" => 100, "errors" => Dict{String, Any}("RMSE" => Any[0.499817130300667, 0.7911532418785379, 1.0699673647641814, 1.6448698438583302, 2.9161078276860364, 4.441838102993554, 5.4805226501910616, 5.9310060700299045, 6.726128873294808, 7.835960605641877, 8.11862248654049], "turning_partition_RMSE" => Any[0.11695063599772217, 0.1774820142192041, 0.39427459138755305, 1.0695569916331593, 2.901882689687128, 5.16308052764138, 5.870284083984321, 6.220183290330493, 6.82845693770239, 9.225200182528736, 9.673182004335173])…)
#  Dict{String, Any}("prediction_type" => "multi_step", "testing_params" => Dict{String, Any}("stochastic" => true, "mask_states_b4_readout" => false, "stochastic_rescale_V_rec" => true, "readout_switching" => false), "data" => "Lorenz 0_01", "num_partitions" => 2, "error_funcs" => Any["RMSE", "turning_partition_RMSE"], "testing_parameter" => "n_steps", "k" => 234, "date" => "2025-03-10", "ignore_first" => 100, "errors" => Dict{String, Any}("RMSE" => Any[0.43987367826737706, 0.691734694011102, 0.9606733472835423, 1.474725329127422, 2.6665784232585126, 3.9005604183849214, 4.747222778971772, 4.788260497487922, 5.863116136011216, 6.951382681741759, 7.63927169272328], "turning_partition_RMSE" => Any[0.1252116675391425, 0.1867974994767286, 0.380476754639661, 0.9872751438740889, 2.671631750835347, 4.635815203340455, 4.718932433567209, 4.361413697562074, 5.144105691971865, 8.305438027804852, 9.074981867557243])…)
#  Dict{String, Any}("prediction_type" => "multi_step", "testing_params" => Dict{String, Any}("stochastic" => true, "mask_states_b4_readout" => false, "stochastic_rescale_V_rec" => true, "readout_switching" => false), "data" => "Lorenz 0_01", "num_partitions" => 6, "error_funcs" => Any["RMSE", "turning_partition_RMSE"], "testing_parameter" => "n_steps", "k" => 78, "date" => "2025-03-10", "ignore_first" => 100, "errors" => Dict{String, Any}("RMSE" => Any[0.6496837267532544, 0.7926485806597956, 1.1093391804720347, 1.43935862534828, 2.1522701654191594, 3.054506248840531, 3.688433695892346, 4.720699764450925, 5.8028555349275415, 6.7225018011504005, 7.985128895336178], "turning_partition_RMSE" => Any[2.627388618552772, 1.808087144724341, 1.5881493843226147, 1.336373064858365, 2.2991357805531485, 3.8870050786924852, 4.093807696547332, 4.1822509458722505, 4.912497747639708, 8.036908025445463, 9.595406543223408])…)
#  Dict{String, Any}("prediction_type" => "multi_step", "testing_params" => Dict{String, Any}("stochastic" => true, "mask_states_b4_readout" => false, "stochastic_rescale_V_rec" => true, "readout_switching" => false), "data" => "Lorenz 0_01", "num_partitions" => 13, "error_funcs" => Any["RMSE", "turning_partition_RMSE"], "testing_parameter" => "n_steps", "k" => 36, "date" => "2025-03-10", "ignore_first" => 100, "errors" => Dict{String, Any}("RMSE" => Any[1.5607682174162567, 33.4623362980144, 34.86652932699376, 46.084262880443156, 70.73951355045732, 94.11425710164032, 111.20156459406579, 131.20228929406625, 137.1576571736013, 159.29159196548497, 180.13766641312878], "turning_partition_RMSE" => Any[6.040163762770957, 4.209456957908825, 48.917383935650314, 120.51655326899417, 126.53506681026195, 139.04825416771803, 118.9606898100644, 125.24441251681569, 140.9939641224224, 165.01989836183023, 188.18063166399668])…)

# %%
test_dict = Dict()

for test in ON_layered_tests
    m_value = "m = " * string(test["m"])
    test_dict[m_value] = test
end

# %%
fig = chart_tests(
    "RMSE vs number of prediction steps",
    "Number of prediction steps",
    "RMSE",
    test_dict,
    metrics=["RMSE"],
    ylim_low=0,
    ylim_high=8.5
)

save("stochastic_OPESN_RMSE_vs_steps.pdf", fig)

fig

# %%
chart_tests(
    "Turning Partition RMSE vs number of prediction steps",
    "Number of prediction steps",
    "Turning Partition RMSE",
    test_dict,
    metrics=["turning_partition_RMSE"],
    ylim_low=0,
    ylim_high=10
)

# %% [markdown]
# # Testing k

# %% [markdown]
# ## Number of steps = 1

# %%
ON_layered_test_search = Dict(
    "prediction_type" => "multi_step",
    "testing_params" => Dict(
        "mask_states_b4_readout" => false,
        "stochastic" => true,
        "stochastic_rescale_V_rec" => true
    ),
    "data" => "Lorenz 0_01",
    "testing_parameter" => "k",
    "ignore_first" => 100,
    "n_steps" => 1,
    "trials" => 30
)
ON_layered_tests = find_test(ON_layered_test_search)

for test in ON_layered_tests
    test["total_k"] = test["k"]*test["num_partitions"]
    test["testing_parameter"] = "total_k"
    println(test["total_k"])
end

ON_layered_tests
# Out:
# No matching test found
#
#
#
# Stacktrace:
#
#  [1] error(s::String)
#
#    @ Base ./error.jl:35
#
#  [2] find_test(test_dict::Dict{String, Any})
#
#    @ Main.TestingFunctions ~/Desktop/Uni/Honours Research/echo-state-networks/Modules/TestingFunctions.jl:564
#
#  [3] top-level scope
#
#    @ ~/Desktop/Uni/Honours Research/echo-state-networks/Notebooks/Hyperparameters/jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X12sZmlsZQ==.jl:14

# %%
test_dict = Dict()

for test in ON_layered_tests
    m_value = "m = " * string(test["m"])
    test_dict[m_value] = test
end

# %%
chart_tests(
    "RMSE vs k_total",
    "k_total",
    "RMSE",
    test_dict,
    metrics=["RMSE"],
    ylim_low = 0
)

# %%
chart_tests(
    "Turning Partition RMSE vs k_total",
    "k",
    "Turning Partition RMSE",
    test_dict,
    metrics=["turning_partition_RMSE"],
    ylim_low = 0
)

# %% [markdown]
# ## Number of steps = 5

# %%
ON_layered_test_search = Dict(
    "prediction_type" => "multi_step",
    "testing_params" => Dict(
        "mask_states_b4_readout" => false,
        "stochastic" => true,
        "stochastic_rescale_V_rec" => true
    ),
    "data" => "Lorenz 0_01",
    "testing_parameter" => "k",
    "ignore_first" => 100,
    "n_steps" => 5,
    "trials" => 30
)
ON_layered_tests = find_test(ON_layered_test_search)

for test in ON_layered_tests
    test["total_k"] = test["k"]*test["num_partitions"]
    test["testing_parameter"] = "total_k"
    println(test["total_k"])
end

ON_layered_tests
# Out:
# No matching test found
#
#
#
# Stacktrace:
#
#  [1] error(s::String)
#
#    @ Base ./error.jl:35
#
#  [2] find_test(test_dict::Dict{String, Any})
#
#    @ Main.TestingFunctions ~/Desktop/Uni/Honours Research/echo-state-networks/Modules/TestingFunctions.jl:564
#
#  [3] top-level scope
#
#    @ ~/Desktop/Uni/Honours Research/echo-state-networks/Notebooks/Hyperparameters/jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X20sZmlsZQ==.jl:14

# %%
test_dict = Dict()

for test in ON_layered_tests
    m_value = "m = " * string(test["m"])
    test_dict[m_value] = test
end

# %%
chart_tests(
    "RMSE vs k_total",
    "k_total",
    "RMSE",
    test_dict,
    metrics=["RMSE"],
    ylim_low = 0,
    ylim_high=2
)

# %%
chart_tests(
    "Turning Partition RMSE vs k_total",
    "k",
    "Turning Partition RMSE",
    test_dict,
    metrics=["turning_partition_RMSE"],
    ylim_low = 0,
    ylim_high=2
)

# %% [markdown]
# ## Number of steps = 50

# %%
ON_layered_test_search = Dict(
    "prediction_type" => "multi_step",
    "testing_params" => Dict(
        "mask_states_b4_readout" => false,
        "stochastic" => true,
        "stochastic_rescale_V_rec" => true
    ),
    "data" => "Lorenz 0_01",
    "testing_parameter" => "k",
    "ignore_first" => 100,
    "n_steps" => 50,
    "trials" => 30
)
ON_layered_tests = find_test(ON_layered_test_search)

for test in ON_layered_tests
    test["total_k"] = test["k"]*test["num_partitions"]
    test["testing_parameter"] = "total_k"
    println(test["total_k"])
end

ON_layered_tests
# Out:
# No matching test found
#
#
#
# Stacktrace:
#
#  [1] error(s::String)
#
#    @ Base ./error.jl:35
#
#  [2] find_test(test_dict::Dict{String, Any})
#
#    @ Main.TestingFunctions ~/Desktop/Uni/Honours Research/echo-state-networks/Modules/TestingFunctions.jl:564
#
#  [3] top-level scope
#
#    @ ~/Desktop/Uni/Honours Research/echo-state-networks/Notebooks/Hyperparameters/jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X26sZmlsZQ==.jl:14

# %%
test_dict = Dict()

for test in ON_layered_tests
    m_value = "m = " * string(test["m"])
    test_dict[m_value] = test
end

# %%
chart_tests(
    "RMSE vs k_total",
    "k_total",
    "RMSE",
    test_dict,
    metrics=["RMSE"],
    ylim_low = 0,
    ylim_high=8
)

# %%
chart_tests(
    "Turning Partition RMSE vs k_total",
    "k",
    "Turning Partition RMSE",
    test_dict,
    metrics=["turning_partition_RMSE"],
    ylim_low = 0,
    ylim_high=8
)
