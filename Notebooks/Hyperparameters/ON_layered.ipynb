# %%
using JSON
using CairoMakie

include("../../Modules/TestingFunctions.jl")
using .TestingFunctions

# %% [markdown]
# # Testing number of steps

# %%
ON_layered_test_search = Dict(
    "prediction_type" => "multi_step",
    "testing_params" => Dict(
        "mask_states_b4_readout" => false,
        "stochastic" => false,
        "stochastic_rescale_V_rec" => false,
        "readout_switching" => false
    ),
    "data" => "Lorenz 0_01",
    "testing_parameter" => "n_steps",
    "ignore_first" => 100,
    "trials" => 30,
    "total_k" => 468
)
ON_layered_tests = find_test(ON_layered_test_search)
# Out:
# 12-element Vector{Any}:
#  Dict{String, Any}("prediction_type" => "multi_step", "testing_params" => Dict{String, Any}("stochastic" => false, "mask_states_b4_readout" => false, "stochastic_rescale_V_rec" => false, "readout_switching" => false), "data" => "Lorenz 0_01", "num_partitions" => 1, "error_funcs" => Any["RMSE", "turning_partition_RMSE"], "testing_parameter" => "n_steps", "k" => 468, "date" => "2025-03-10", "ignore_first" => 100, "errors" => Dict{String, Any}("RMSE" => Any[0.4999211637999944, 0.7834680069819627, 1.0635266687215208, 1.6650214158953391, 2.855424208989064, 4.457236847633764, 5.708085711799096, 5.739134789838322, 6.661291801535499, 7.586993919122104, 8.110850854282251], "turning_partition_RMSE" => Any[0.11677539858380946, 0.178979881671493, 0.3928768008472971, 1.068676252513262, 2.8539564786794243, 5.203312596513466, 6.151243422827574, 5.965578368413002, 6.660207645397867, 8.915324019391697, 9.643034316608212])…)
#  Dict{String, Any}("prediction_type" => "multi_step", "testing_params" => Dict{String, Any}("stochastic" => false, "mask_states_b4_readout" => false, "stochastic_rescale_V_rec" => false, "readout_switching" => false), "data" => "Lorenz 0_01", "num_partitions" => 2, "error_funcs" => Any["RMSE", "turning_partition_RMSE"], "testing_parameter" => "n_steps", "k" => 234, "date" => "2025-03-10", "ignore_first" => 100, "errors" => Dict{String, Any}("RMSE" => Any[0.4424195228724751, 0.7087112677072894, 0.961898106510936, 1.5129325449379825, 2.644892340719517, 4.092792197527498, 4.895088745181805, 4.9550977743838, 6.002633988631778, 7.071390253832137, 7.656531139030247], "turning_partition_RMSE" => Any[0.12491120262712503, 0.18623568901294765, 0.3824070676683148, 0.9863473575956888, 2.646172072354803, 4.77913494101414, 4.898478726898632, 4.692139960788381, 5.353425505831864, 8.450036204093683, 9.09703002631355])…)
#  Dict{String, Any}("prediction_type" => "multi_step", "testing_params" => Dict{String, Any}("stochastic" => false, "mask_states_b4_readout" => false, "stochastic_rescale_V_rec" => false, "readout_switching" => false), "data" => "Lorenz 0_01", "num_partitions" => 6, "error_funcs" => Any["RMSE", "turning_partition_RMSE"], "testing_parameter" => "n_steps", "k" => 78, "date" => "2025-03-10", "ignore_first" => 100, "errors" => Dict{String, Any}("RMSE" => Any[0.6594377499460161, 0.7913807937110431, 1.1199259247103373, 1.3956371257820022, 2.188338377711168, 3.107750244388648, 3.6435825026431266, 4.638191791480179, 5.725221004466485, 6.802586303344605, 7.912011594925187], "turning_partition_RMSE" => Any[2.6847117774438454, 1.8382206873767322, 1.6223260670935353, 1.387600388428031, 2.389193940754673, 3.942357754218704, 4.141519144776037, 4.258356215589678, 4.791951505066992, 8.081314394975136, 9.464580172200026])…)
=> Any[0.2679361424707349, 0.2827325567420176, 0.3938956872302137, 0.6296864527212659, 1.024944462862813, 0.8940034666428961, 1.0641286797931808, 0.875925694069911, 0.8306366336481195, 1.0555180971978941, 0.9706851806574706]), "turning_partition_RMSE" => Dict{String, Any}("minimum" => Any[4.808349787979314, 3.6275292020097494, 3.410533151936717, 3.698352079597701, 4.301852537746192, 4.58794715330672, 3.7710920339546, 5.298360090207744, 6.616442782888976, 10.144485415177257, 10.915232299224618], "median" => Any[6.719648520280792, 4.964721720651355, 4.550751265942706, 5.490578555950498, 7.2171514833074335, 8.64292797544283, 7.290174419123427, 8.037792736893085, 8.084676817320862, 11.59248947736749, 11.716972597500236], "mean" => Any[6.8319488023214054, 4.880479415067459, 4.49945612285233, 5.912978346133111, 7.7999835082772755, 8.94166650896795, 7.456316688375177, 8.288188609184244, 8.354001876809125, 11.662300602892957, 11.9971677306904], "maximum" => Any[8.97096709733012, 6.6039781168167035, 5.458859649224807, 9.622268092561889, 19.15158416114735, 14.354333770131324, 12.433990795978843, 12.483728471022125, 11.524301406718655, 15.213445382019836, 15.18176797355031], "std" => Any[1.1202266869737807, 0.6381357183094893, 0.5404671483885914, 1.6118413028179415, 2.6813552538283933, 2.062720015282012, 1.7978872449668557, 1.4719739761669737, 1.4268195423187546, 1.0039095298890182, 0.965791404415579])), "k" => 36, "date" => "2025-03-21", "ignore_first" => 100…)

# %%
test_dict = Dict()

for test in ON_layered_tests
    m_value = "m = " * string(test["m"])
    test_dict[m_value] = test
end

# %%
fig = chart_tests(
    "RMSE vs number of prediction steps",
    "Number of prediction steps",
    "RMSE",
    test_dict,
    error_funcs=["RMSE"],
    aggregation_funcs=["mean"],
    ylim_low=0,
    ylim_high=8.5
)

save("RMSE_vs_number_of_prediction_steps.pdf", fig)

fig

# %%
chart_tests(
    "Turning Partition RMSE vs number of prediction steps",
    "Number of prediction steps",
    "Turning Partition RMSE",
    test_dict,
    error_funcs=["turning_partition_RMSE"],
    aggregation_funcs=["mean"],
    ylim_low=0,
    ylim_high=10
)

# %%
ON_layered_test_search = Dict(
    "prediction_type" => "multi_step",
    "testing_params" => Dict(
        "mask_states_b4_readout" => false,
        "stochastic" => false,
        "stochastic_rescale_V_rec" => false,
        "readout_switching" => false
    ),
    "data" => "Rossler 0_01",
    "testing_parameter" => "n_steps",
    "ignore_first" => 100,
    "trials" => 30,
    "total_k" => 468
)
ON_layered_tests = find_test(ON_layered_test_search)
# Out:
# 2-element Vector{Any}:
#  Dict{String, Any}("prediction_type" => "multi_step", "testing_params" => Dict{String, Any}("stochastic" => false, "mask_states_b4_readout" => false, "stochastic_rescale_V_rec" => false, "readout_switching" => false), "data" => "Rossler 0_01", "num_partitions" => 1, "error_funcs" => Any["RMSE", "turning_partition_RMSE"], "testing_parameter" => "n_steps", "measurements" => Dict{String, Any}("RMSE" => Dict{String, Any}("minimum" => Any[0.05368301547067279, 0.08478336969213376, 0.11585186391132281, 0.16990907083886495, 0.32128531343476086, 0.6149100570181227, 0.8702716377655837
793333839762], "mean" => Any[0.05212931852487136, 0.08005864154804757, 0.11149068057254909, 0.1709226323284069, 0.32935502726216814, 0.639118645224184, 0.9594838015964188, 1.2706900846817368, 1.5077388020557558], "maximum" => Any[0.057443311689841944, 0.08542102529460464, 0.12017652902538564, 0.1970545764469695, 0.4118112410065794, 0.9724351261494907, 1.3686596864167921, 1.8697784055393132, 1.9086452690013025], "std" => Any[0.0021028886215473204, 0.0026998418991271357, 0.004405395662465446, 0.010574123947816667, 0.029084820246631317, 0.09870458752574898, 0.12535145500110492, 0.20898349652813308, 0.1499847337186258]), "turning_partition_RMSE" => Dict{String, Any}("minimum" => Any[0.0021329735790527405, 0.002181545554279849, 0.005223840370621381, 0.016968681696989136, 0.07755775323486315, 0.1837516295659478, 0.2662661218642652, 0.35670257710151315, 0.6404633034158517], "median" => Any[0.0024193346617450862, 0.0027325678358495645, 0.0240842024876918, 0.09812818392735817, 0.2548023761841077, 0.5388922891687196, 0.8452016144574668, 1.0182474932177654, 1.3431062987256004], "mean" => Any[0.002432344310554704, 0.002792034140380142, 0.03726090099295521, 0.09608790503898051, 0.2834584575355228, 0.594422086981847, 0.9143502728962162, 1.2739131621076072, 1.4393039851562681], "maximum" => Any[0.0027287580436646044, 0.003747948762819723, 0.16072639013601916, 0.20920450822254047, 0.7927412015739234, 1.7136293134025415, 1.7172658895848645, 3.012606514086956, 2.4018100637296445], "std" => Any[0.00014742128893737355, 0.0003454189840856911, 0.033168549785127927, 0.057387825632901505, 0.1751805803138305, 0.33768792899149186, 0.36628958533564304, 0.6536109626093218, 0.460625946939097])), "k" => 234, "date" => "2025-03-21", "ignore_first" => 100…)

# %%
test_dict = Dict()

for test in ON_layered_tests
    m_value = "m = " * string(test["m"])
    test_dict[m_value] = test
end

# %%
fig = chart_tests(
    "RMSE vs number of prediction steps",
    "Number of prediction steps",
    "RMSE",
    test_dict,
    error_funcs=["RMSE"],
    aggregation_funcs=["mean"]
    # ylim_low=0,
    # ylim_high=8.5
)

save("RMSE_vs_number_of_prediction_steps.pdf", fig)

fig

# %%
chart_tests(
    "Turning Partition RMSE vs number of prediction steps",
    "Number of prediction steps",
    "Turning Partition RMSE",
    test_dict,
    error_funcs=["turning_partition_RMSE"],
    aggregation_funcs=["mean"]
    # ylim_low=0,
    # ylim_high=10
)

# %% [markdown]
# # Testing k

# %% [markdown]
# ## Number of steps = 1

# %%
ON_layered_test_search = Dict(
    "prediction_type" => "multi_step",
    "testing_params" => Dict(
        "mask_states_b4_readout" => false,
        "stochastic" => false,
        "stochastic_rescale_V_rec" => false
    ),
    "data" => "Lorenz 0_01",
    "testing_parameter" => "k",
    "ignore_first" => 100,
    "n_steps" => 1,
    "trials" => 30
)
ON_layered_tests = find_test(ON_layered_test_search)

for test in ON_layered_tests
    test["total_k"] = test["k"]*test["num_partitions"]
    test["testing_parameter"] = "total_k"
    println(test["total_k"])
end

ON_layered_tests
# Out:
# No matching test found
#
#
#
# Stacktrace:
#
#  [1] error(s::String)
#
#    @ Base ./error.jl:35
#
#  [2] find_test(test_dict::Dict{String, Any})
#
#    @ Main.TestingFunctions ~/Desktop/Uni/Honours Research/echo-state-networks/Modules/TestingFunctions.jl:651
#
#  [3] top-level scope
#
#    @ ~/Desktop/Uni/Honours Research/echo-state-networks/Notebooks/Hyperparameters/jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X12sZmlsZQ==.jl:14

# %%
test_dict = Dict()

for test in ON_layered_tests
    m_value = "m = " * string(test["m"])
    test_dict[m_value] = test
end

# %%
chart_tests(
    "RMSE vs k_total",
    "k_total",
    "RMSE",
    test_dict,
    metrics=["RMSE"]
)
# Out:
# MethodError: no method matching chart_tests(::String, ::String, ::String, ::Dict{Any, Any}; metrics::Vector{String})
#
#
#
# Closest candidates are:
#
#   chart_tests(::Any, ::Any, ::Any, ::Any; error_funcs, aggregation_funcs, bottom_margin, ylim_low, ylim_high) got unsupported keyword argument "metrics"
#
#    @ Main.TestingFunctions ~/Desktop/Uni/Honours Research/echo-state-networks/Modules/TestingFunctions.jl:656
#
#
#
#
#
# Stacktrace:
#
#  [1] kwerr(::@NamedTuple{metrics::Vector{String}}, ::Function, ::String, ::String, ::String, ::Dict{Any, Any})
#
#    @ Base ./error.jl:165
#
#  [2] top-level scope
#
#    @ ~/Desktop/Uni/Honours Research/echo-state-networks/Notebooks/Hyperparameters/jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X14sZmlsZQ==.jl:1

# %%
chart_tests(
    "Turning Partition RMSE vs k_total",
    "k",
    "Turning Partition RMSE",
    test_dict,
    metrics=["turning_partition_RMSE"]
)
# Out:
# MethodError: no method matching chart_tests(::String, ::String, ::String, ::Dict{Any, Any}; metrics::Vector{String})
#
#
#
# Closest candidates are:
#
#   chart_tests(::Any, ::Any, ::Any, ::Any; error_funcs, aggregation_funcs, bottom_margin, ylim_low, ylim_high) got unsupported keyword argument "metrics"
#
#    @ Main.TestingFunctions ~/Desktop/Uni/Honours Research/echo-state-networks/Modules/TestingFunctions.jl:656
#
#
#
#
#
# Stacktrace:
#
#  [1] kwerr(::@NamedTuple{metrics::Vector{String}}, ::Function, ::String, ::String, ::String, ::Dict{Any, Any})
#
#    @ Base ./error.jl:165
#
#  [2] top-level scope
#
#    @ ~/Desktop/Uni/Honours Research/echo-state-networks/Notebooks/Hyperparameters/jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X15sZmlsZQ==.jl:1

# %% [markdown]
# ## Number of steps = 5

# %%
ON_layered_test_search = Dict(
    "prediction_type" => "multi_step",
    "testing_params" => Dict(
        "mask_states_b4_readout" => false,
        "stochastic" => false,
        "stochastic_rescale_V_rec" => false
    ),
    "data" => "Lorenz 0_01",
    "testing_parameter" => "k",
    "ignore_first" => 100,
    "n_steps" => 5,
    "trials" => 30
)
ON_layered_tests = find_test(ON_layered_test_search)

for test in ON_layered_tests
    test["total_k"] = test["k"]*test["num_partitions"]
    test["testing_parameter"] = "total_k"
    println(test["total_k"])
end

ON_layered_tests
# Out:
# No matching test found
#
#
#
# Stacktrace:
#
#  [1] error(s::String)
#
#    @ Base ./error.jl:35
#
#  [2] find_test(test_dict::Dict{String, Any})
#
#    @ Main.TestingFunctions ~/Desktop/Uni/Honours Research/echo-state-networks/Modules/TestingFunctions.jl:651
#
#  [3] top-level scope
#
#    @ ~/Desktop/Uni/Honours Research/echo-state-networks/Notebooks/Hyperparameters/jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X20sZmlsZQ==.jl:14

# %%
test_dict = Dict()

for test in ON_layered_tests
    m_value = "m = " * string(test["m"])
    test_dict[m_value] = test
end

# %%
chart_tests(
    "RMSE vs k_total",
    "k_total",
    "RMSE",
    test_dict,
    metrics=["RMSE"],
    ylim_low = 0,
    ylim_high=2
)
# Out:
# MethodError: no method matching chart_tests(::String, ::String, ::String, ::Dict{Any, Any}; metrics::Vector{String}, ylim_low::Int64, ylim_high::Int64)
#
#
#
# Closest candidates are:
#
#   chart_tests(::Any, ::Any, ::Any, ::Any; error_funcs, aggregation_funcs, bottom_margin, ylim_low, ylim_high) got unsupported keyword argument "metrics"
#
#    @ Main.TestingFunctions ~/Desktop/Uni/Honours Research/echo-state-networks/Modules/TestingFunctions.jl:656
#
#
#
#
#
# Stacktrace:
#
#  [1] kwerr(::@NamedTuple{metrics::Vector{String}, ylim_low::Int64, ylim_high::Int64}, ::Function, ::String, ::String, ::String, ::Dict{Any, Any})
#
#    @ Base ./error.jl:165
#
#  [2] top-level scope
#
#    @ ~/Desktop/Uni/Honours Research/echo-state-networks/Notebooks/Hyperparameters/jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X22sZmlsZQ==.jl:1

# %%
chart_tests(
    "Turning Partition RMSE vs k_total",
    "k",
    "Turning Partition RMSE",
    test_dict,
    metrics=["turning_partition_RMSE"],
    ylim_low = 0,
    ylim_high=2
)
# Out:
# MethodError: no method matching chart_tests(::String, ::String, ::String, ::Dict{Any, Any}; metrics::Vector{String}, ylim_low::Int64, ylim_high::Int64)
#
#
#
# Closest candidates are:
#
#   chart_tests(::Any, ::Any, ::Any, ::Any; error_funcs, aggregation_funcs, bottom_margin, ylim_low, ylim_high) got unsupported keyword argument "metrics"
#
#    @ Main.TestingFunctions ~/Desktop/Uni/Honours Research/echo-state-networks/Modules/TestingFunctions.jl:656
#
#
#
#
#
# Stacktrace:
#
#  [1] kwerr(::@NamedTuple{metrics::Vector{String}, ylim_low::Int64, ylim_high::Int64}, ::Function, ::String, ::String, ::String, ::Dict{Any, Any})
#
#    @ Base ./error.jl:165
#
#  [2] top-level scope
#
#    @ ~/Desktop/Uni/Honours Research/echo-state-networks/Notebooks/Hyperparameters/jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X23sZmlsZQ==.jl:1

# %% [markdown]
# ## Number of steps = 50

# %%
ON_layered_test_search = Dict(
    "prediction_type" => "multi_step",
    "testing_params" => Dict(
        "mask_states_b4_readout" => false,
        "stochastic" => false,
        "stochastic_rescale_V_rec" => false
    ),
    "data" => "Lorenz 0_01",
    "testing_parameter" => "k",
    "ignore_first" => 100,
    "n_steps" => 50,
    "trials" => 30
)
ON_layered_tests = find_test(ON_layered_test_search)

for test in ON_layered_tests
    test["total_k"] = test["k"]*test["num_partitions"]
    test["testing_parameter"] = "total_k"
    println(test["total_k"])
end

ON_layered_tests
# Out:
# No matching test found
#
#
#
# Stacktrace:
#
#  [1] error(s::String)
#
#    @ Base ./error.jl:35
#
#  [2] find_test(test_dict::Dict{String, Any})
#
#    @ Main.TestingFunctions ~/Desktop/Uni/Honours Research/echo-state-networks/Modules/TestingFunctions.jl:651
#
#  [3] top-level scope
#
#    @ ~/Desktop/Uni/Honours Research/echo-state-networks/Notebooks/Hyperparameters/jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X26sZmlsZQ==.jl:14

# %%
test_dict = Dict()

for test in ON_layered_tests
    m_value = "m = " * string(test["m"])
    test_dict[m_value] = test
end

# %%
chart_tests(
    "RMSE vs k_total",
    "k_total",
    "RMSE",
    test_dict,
    metrics=["RMSE"],
    ylim_low = 0,
    ylim_high=8
)
# Out:
# MethodError: no method matching chart_tests(::String, ::String, ::String, ::Dict{Any, Any}; metrics::Vector{String}, ylim_low::Int64, ylim_high::Int64)
#
#
#
# Closest candidates are:
#
#   chart_tests(::Any, ::Any, ::Any, ::Any; error_funcs, aggregation_funcs, bottom_margin, ylim_low, ylim_high) got unsupported keyword argument "metrics"
#
#    @ Main.TestingFunctions ~/Desktop/Uni/Honours Research/echo-state-networks/Modules/TestingFunctions.jl:656
#
#
#
#
#
# Stacktrace:
#
#  [1] kwerr(::@NamedTuple{metrics::Vector{String}, ylim_low::Int64, ylim_high::Int64}, ::Function, ::String, ::String, ::String, ::Dict{Any, Any})
#
#    @ Base ./error.jl:165
#
#  [2] top-level scope
#
#    @ ~/Desktop/Uni/Honours Research/echo-state-networks/Notebooks/Hyperparameters/jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X31sZmlsZQ==.jl:1

# %%
chart_tests(
    "Turning Partition RMSE vs k_total",
    "k",
    "Turning Partition RMSE",
    test_dict,
    metrics=["turning_partition_RMSE"],
    ylim_low = 0,
    ylim_high=8
)
# Out:
# MethodError: no method matching chart_tests(::String, ::String, ::String, ::Dict{Any, Any}; metrics::Vector{String}, ylim_low::Int64, ylim_high::Int64)
#
#
#
# Closest candidates are:
#
#   chart_tests(::Any, ::Any, ::Any, ::Any; error_funcs, aggregation_funcs, bottom_margin, ylim_low, ylim_high) got unsupported keyword argument "metrics"
#
#    @ Main.TestingFunctions ~/Desktop/Uni/Honours Research/echo-state-networks/Modules/TestingFunctions.jl:656
#
#
#
#
#
# Stacktrace:
#
#  [1] kwerr(::@NamedTuple{metrics::Vector{String}, ylim_low::Int64, ylim_high::Int64}, ::Function, ::String, ::String, ::String, ::Dict{Any, Any})
#
#    @ Base ./error.jl:165
#
#  [2] top-level scope
#
#    @ ~/Desktop/Uni/Honours Research/echo-state-networks/Notebooks/Hyperparameters/jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X32sZmlsZQ==.jl:1

# %% [markdown]
# # Other tests

# %% [markdown]
# ## m = 3, k = 50

# %%
ON_layered_test_search = Dict(
    "prediction_type" => "multi_step",
    "testing_params" => Dict(
        "mask_states_b4_readout" => false,
        "stochastic" => false,
        "stochastic_rescale_V_rec" => false
    ),
    "data" => "Lorenz 0_01",
    "testing_parameter" => "n_steps",
    "k" => 50,
    "ignore_first" => 100,
    "m" => 3,
    "trials" => 30
)
ON_layered_tests = find_test(ON_layered_test_search)[1];

vanilla_test_search = copy(ON_layered_test_search)
vanilla_test_search["m"] = 1
vanilla_test_search["k"] = 300
vanilla_test = find_test(vanilla_test_search)[1];

test_dict = Dict(
    "Vanilla ESN" => vanilla_test,
    "ON Layered ESN" => ON_layered_test
)

chart_tests(
    "RMSE vs number of prediction steps",
    "Number of prediction steps",
    "RMSE",
    test_dict
)
# Out:
# No matching test found
#
#
#
# Stacktrace:
#
#  [1] error(s::String)
#
#    @ Base ./error.jl:35
#
#  [2] find_test(test_dict::Dict{String, Any})
#
#    @ Main.TestingFunctions ~/Desktop/Uni/Honours Research/echo-state-networks/Modules/TestingFunctions.jl:651
#
#  [3] top-level scope
#
#    @ ~/Desktop/Uni/Honours Research/echo-state-networks/Notebooks/Hyperparameters/jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X36sZmlsZQ==.jl:14

# %%
ON_layered_turning_test_search = copy(ON_layered_test_search)
ON_layered_turning_test_search["error_func"] = "turning_partition_RMSE"
ON_layered_turning_test = find_test(ON_layered_turning_test_search)[1];

vanilla_turning_test_search = copy(ON_layered_turning_test_search)
vanilla_turning_test_search["m"] = 1
vanilla_turning_test_search["k"] = 300
vanilla_turning_test = find_test(vanilla_turning_test_search)[1];

chart_tests(
    "Turning RMSE vs number of prediction steps",
    "Number of prediction steps",
    "Turning RMSE",
    Dict(
        "Vanilla ESN" => vanilla_turning_test,
        "ON Layered ESN" => ON_layered_turning_test
    )
)
# Out:
# No matching test found
#
#
#
# Stacktrace:
#
#  [1] error(s::String)
#
#    @ Base ./error.jl:35
#
#  [2] find_test(test_dict::Dict{String, Any})
#
#    @ Main.TestingFunctions ~/Desktop/Uni/Honours Research/echo-state-networks/Modules/TestingFunctions.jl:651
#
#  [3] top-level scope
#
#    @ ~/Desktop/Uni/Honours Research/echo-state-networks/Notebooks/Hyperparameters/jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X40sZmlsZQ==.jl:2

# %% [markdown]
# ## m = 3, k = 100

# %%
ON_layered_test_search["k"] = 100
ON_layered_test = find_test(ON_layered_test_search)[1];

vanilla_test_search["k"] = 600
vanilla_test = find_test(vanilla_test_search)[1];

chart_tests(
    "RMSE vs number of prediction steps",
    "Number of prediction steps",
    "RMSE",
    Dict(
        "Vanilla ESN" => vanilla_test,
        "ON Layered ESN" => ON_layered_test
    )
)
# Out:
# No matching test found
#
#
#
# Stacktrace:
#
#  [1] error(s::String)
#
#    @ Base ./error.jl:35
#
#  [2] find_test(test_dict::Dict{String, Any})
#
#    @ Main.TestingFunctions ~/Desktop/Uni/Honours Research/echo-state-networks/Modules/TestingFunctions.jl:651
#
#  [3] top-level scope
#
#    @ ~/Desktop/Uni/Honours Research/echo-state-networks/Notebooks/Hyperparameters/jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X42sZmlsZQ==.jl:1

# %%
ON_layered_turning_test_search["k"] = 100
ON_layered_turning_test = find_test(ON_layered_turning_test_search)[1];

vanilla_turning_test_search["k"] = 600
vanilla_turning_test = find_test(vanilla_turning_test_search)[1];

chart_tests(
    "Turning RMSE vs number of prediction steps",
    "Number of prediction steps",
    "Turning RMSE",
    Dict(
        "Vanilla ESN" => vanilla_turning_test,
        "ON Layered ESN" => ON_layered_turning_test
    )
)
# Out:
# No matching test found
#
#
#
# Stacktrace:
#
#  [1] error(s::String)
#
#    @ Base ./error.jl:35
#
#  [2] find_test(test_dict::Dict{String, Any})
#
#    @ Main.TestingFunctions ~/Desktop/Uni/Honours Research/echo-state-networks/Modules/TestingFunctions.jl:651
#
#  [3] top-level scope
#
#    @ ~/Desktop/Uni/Honours Research/echo-state-networks/Notebooks/Hyperparameters/jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X43sZmlsZQ==.jl:1

# %% [markdown]
# ## m = 4, k = 50

# %%
ON_layered_test_search = Dict(
    "prediction_type" => "multi_step",
    "testing_params" => Dict(
        "mask_states_b4_readout" => false,
        "stochastic" => false,
        "stochastic_rescale_V_rec" => false
    ),
    "data" => "Lorenz 0_01",
    "testing_parameter" => "n_steps",
    "k" => 50,
    "ignore_first" => 100,
    "m" => 4,
    "trials" => 30
)
ON_layered_test = find_test(ON_layered_test_search)[1];

vanilla_test_search = copy(ON_layered_test_search)
vanilla_test_search["m"] = 1
vanilla_test_search["k"] = 650
vanilla_test = find_test(vanilla_test_search)[1];

chart_tests(
    "RMSE vs number of prediction steps",
    "Number of prediction steps",
    "RMSE",
    Dict(
        "Vanilla ESN" => vanilla_test,
        "ON Layered ESN" => ON_layered_test
    )
)
# Out:
# No matching test found
#
#
#
# Stacktrace:
#
#  [1] error(s::String)
#
#    @ Base ./error.jl:35
#
#  [2] find_test(test_dict::Dict{String, Any})
#
#    @ Main.TestingFunctions ~/Desktop/Uni/Honours Research/echo-state-networks/Modules/TestingFunctions.jl:651
#
#  [3] top-level scope
#
#    @ ~/Desktop/Uni/Honours Research/echo-state-networks/Notebooks/Hyperparameters/jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X45sZmlsZQ==.jl:14

# %%
ON_layered_turning_test_search = copy(ON_layered_test_search)
ON_layered_turning_test_search["error_func"] = "turning_partition_RMSE"
ON_layered_turning_test = find_test(ON_layered_turning_test_search)[1];

vanilla_turning_test_search = copy(vanilla_test_search)
vanilla_turning_test_search["error_func"] = "turning_partition_RMSE"
vanilla_turning_test = find_test(vanilla_turning_test_search)[1];

chart_tests(
    "Turning RMSE vs number of prediction steps",
    "Number of prediction steps",
    "Turning RMSE",
    Dict(
        "Vanilla ESN" => vanilla_turning_test,
        "ON Layered ESN" => ON_layered_turning_test
    )
)
# Out:
# No matching test found
#
#
#
# Stacktrace:
#
#  [1] error(s::String)
#
#    @ Base ./error.jl:35
#
#  [2] find_test(test_dict::Dict{String, Any})
#
#    @ Main.TestingFunctions ~/Desktop/Uni/Honours Research/echo-state-networks/Modules/TestingFunctions.jl:651
#
#  [3] top-level scope
#
#    @ ~/Desktop/Uni/Honours Research/echo-state-networks/Notebooks/Hyperparameters/jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X46sZmlsZQ==.jl:2

# %%
ON_layered_test
# Out:
# UndefVarError: `ON_layered_test` not defined

# %% [markdown]
# ## m = 4, k = 100

# %%
ON_layered_test_search = Dict(
    "prediction_type" => "multi_step",
    "testing_params" => Dict(
        "mask_states_b4_readout" => false,
        "stochastic" => false,
        "stochastic_rescale_V_rec" => false
    ),
    "data" => "Lorenz 0_01",
    "testing_parameter" => "n_steps",
    "k" => 100,
    "ignore_first" => 100,
    "m" => 4,
    "trials" => 30
)
ON_layered_test = find_test(ON_layered_test_search)[1];

vanilla_test_search = copy(ON_layered_test_search)
vanilla_test_search["m"] = 1
vanilla_test_search["k"] = 1300
vanilla_test = find_test(vanilla_test_search)[1];

chart_tests(
    "RMSE vs number of prediction steps",
    "Number of prediction steps",
    "RMSE",
    Dict(
        "Vanilla ESN" => vanilla_test,
        "ON Layered ESN" => ON_layered_test
    )
)
# Out:
# No matching test found
#
#
#
# Stacktrace:
#
#  [1] error(s::String)
#
#    @ Base ./error.jl:35
#
#  [2] find_test(test_dict::Dict{String, Any})
#
#    @ Main.TestingFunctions ~/Desktop/Uni/Honours Research/echo-state-networks/Modules/TestingFunctions.jl:651
#
#  [3] top-level scope
#
#    @ ~/Desktop/Uni/Honours Research/echo-state-networks/Notebooks/Hyperparameters/jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X52sZmlsZQ==.jl:14

# %%
ON_layered_turning_test_search = copy(ON_layered_test_search)
ON_layered_turning_test_search["error_func"] = "turning_partition_RMSE"
ON_layered_turning_test = find_test(ON_layered_turning_test_search)[1];

vanilla_turning_test_search = copy(vanilla_test_search)
vanilla_turning_test_search["error_func"] = "turning_partition_RMSE"
vanilla_turning_test = find_test(vanilla_turning_test_search)[1];

chart_tests(
    "Turning RMSE vs number of prediction steps",
    "Number of prediction steps",
    "Turning RMSE",
    Dict(
        "Vanilla ESN" => vanilla_turning_test,
        "ON Layered ESN" => ON_layered_turning_test
    )
)
# Out:
# No matching test found
#
#
#
# Stacktrace:
#
#  [1] error(s::String)
#
#    @ Base ./error.jl:35
#
#  [2] find_test(test_dict::Dict{String, Any})
#
#    @ Main.TestingFunctions ~/Desktop/Uni/Honours Research/echo-state-networks/Modules/TestingFunctions.jl:651
#
#  [3] top-level scope
#
#    @ ~/Desktop/Uni/Honours Research/echo-state-networks/Notebooks/Hyperparameters/jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X53sZmlsZQ==.jl:2
