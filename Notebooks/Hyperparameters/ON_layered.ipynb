# %%
using JSON
using CairoMakie

include("../../Modules/TestingFunctions.jl")
using .TestingFunctions
# Out:
# WARNING: replacing module TestingFunctions.
# WARNING: using TestingFunctions.find_test in module Main conflicts with an existing identifier.
# WARNING: using TestingFunctions.chart_tests in module Main conflicts with an existing identifier.

# %% [markdown]
# # Testing number of steps

# %%
ON_layered_test_search = Dict(
    "prediction_type" => "multi_step",
    "testing_params" => Dict(
        "mask_states_b4_readout" => false,
        "stochastic" => false,
        "stochastic_rescale_V_rec" => false
    ),
    "data" => "Lorenz 0_01",
    "testing_parameter" => "n_steps",
    "ignore_first" => 100,
    "trials" => 30,
    "total_k" => 468
)
ON_layered_tests = find_test(ON_layered_test_search)
# Out:
# 4-element Vector{Any}:
#  Dict{String, Any}("prediction_type" => "multi_step", "testing_params" => Dict{String, Any}("stochastic" => false, "mask_states_b4_readout" => false, "stochastic_rescale_V_rec" => false), "data" => "Lorenz 0_01", "num_partitions" => 1, "error_funcs" => Any["RMSE", "turning_partition_RMSE"], "testing_parameter" => "n_steps", "k" => 468, "date" => "2025-03-10", "ignore_first" => 100, "errors" => Dict{String, Any}("RMSE" => Any[0.4999211637999944, 0.7834680069819627, 1.0635266687215208, 1.6650214158953391, 2.855424208989064, 4.457236847633764, 5.708085711799096, 5.739134789838322, 6.661291801535499, 7.586993919122104, 8.110850854282251], "turning_partition_RMSE" => Any[0.11677539858380946, 0.178979881671493, 0.3928768008472971, 1.068676252513262, 2.8539564786794243, 5.203312596513466, 6.151243422827574, 5.965578368413002, 6.660207645397867, 8.915324019391697, 9.643034316608212])…)
#  Dict{String, Any}("prediction_type" => "multi_step", "testing_params" => Dict{String, Any}("stochastic" => false, "mask_states_b4_readout" => false, "stochastic_rescale_V_rec" => false), "data" => "Lorenz 0_01", "num_partitions" => 2, "error_funcs" => Any["RMSE", "turning_partition_RMSE"], "testing_parameter" => "n_steps", "k" => 234, "date" => "2025-03-10", "ignore_first" => 100, "errors" => Dict{String, Any}("RMSE" => Any[0.4424195228724751, 0.7087112677072894, 0.961898106510936, 1.5129325449379825, 2.644892340719517, 4.092792197527498, 4.895088745181805, 4.9550977743838, 6.002633988631778, 7.071390253832137, 7.656531139030247], "turning_partition_RMSE" => Any[0.12491120262712503, 0.18623568901294765, 0.3824070676683148, 0.9863473575956888, 2.646172072354803, 4.77913494101414, 4.898478726898632, 4.692139960788381, 5.353425505831864, 8.450036204093683, 9.09703002631355])…)
#  Dict{String, Any}("prediction_type" => "multi_step", "testing_params" => Dict{String, Any}("stochastic" => false, "mask_states_b4_readout" => false, "stochastic_rescale_V_rec" => false), "data" => "Lorenz 0_01", "num_partitions" => 6, "error_funcs" => Any["RMSE", "turning_partition_RMSE"], "testing_parameter" => "n_steps", "k" => 78, "date" => "2025-03-10", "ignore_first" => 100, "errors" => Dict{String, Any}("RMSE" => Any[0.6594377499460161, 0.7913807937110431, 1.1199259247103373, 1.3956371257820022, 2.188338377711168, 3.107750244388648, 3.6435825026431266, 4.638191791480179, 5.725221004466485, 6.802586303344605, 7.912011594925187], "turning_partition_RMSE" => Any[2.6847117774438454, 1.8382206873767322, 1.6223260670935353, 1.387600388428031, 2.389193940754673, 3.942357754218704, 4.141519144776037, 4.258356215589678, 4.791951505066992, 8.081314394975136, 9.464580172200026])…)
#  Dict{String, Any}("prediction_type" => "multi_step", "testing_params" => Dict{String, Any}("stochastic" => false, "mask_states_b4_readout" => false, "stochastic_rescale_V_rec" => false), "data" => "Lorenz 0_01", "num_partitions" => 13, "error_funcs" => Any["RMSE", "turning_partition_RMSE"], "testing_parameter" => "n_steps", "k" => 36, "date" => "2025-03-10", "ignore_first" => 100, "errors" => Dict{String, Any}("RMSE" => Any[1.7130744562437188, 34.40346805197592, 35.37619380659681, 49.614439136698586, 69.57928639980287, 108.49331961264154, 124.35183586145457, 154.79677597074223, 162.1341823256021, 173.30757077000493, 173.10511963281562], "turning_partition_RMSE" => Any[6.298435588294511, 4.6706889882449865, 48.05394590656356, 116.63746724813763, 121.48866466833655, 156.7131483473095, 134.6453777942244, 147.83955759486287, 168.84348555301733, 177.87459561510704, 183.78802536751124])…)

# %%
test_dict = Dict()

for test in ON_layered_tests
    m_value = "m = " * string(test["m"])
    test_dict[m_value] = test
end

# %%
chart_tests(
    "RMSE vs number of prediction steps",
    "Number of prediction steps",
    "RMSE",
    test_dict,
    metrics=["RMSE"],
    ylim_low=0,
    ylim_high=8.5
)

# %%
chart_tests(
    "Turning Partition RMSE vs number of prediction steps",
    "Number of prediction steps",
    "Turning Partition RMSE",
    test_dict,
    metrics=["turning_partition_RMSE"],
    ylim_low=0,
    ylim_high=10
)

# %% [markdown]
# # Testing k

# %% [markdown]
# ## Number of steps = 1

# %%
ON_layered_test_search = Dict(
    "prediction_type" => "multi_step",
    "testing_params" => Dict(
        "mask_states_b4_readout" => false,
        "stochastic" => false,
        "stochastic_rescale_V_rec" => false
    ),
    "data" => "Lorenz 0_01",
    "testing_parameter" => "k",
    "ignore_first" => 100,
    "n_steps" => 1,
    "trials" => 30
)
ON_layered_tests = find_test(ON_layered_test_search)

for test in ON_layered_tests
    test["total_k"] = test["k"]*test["num_partitions"]
    test["testing_parameter"] = "total_k"
    println(test["total_k"])
end

ON_layered_tests
# Out:
# [156, 312, 624, 1248]
# [156, 312, 624, 1248]
# [156, 312, 624, 1248]
# [156, 312, 624, 1248]
# [156, 312, 624, 1248]
# 5-element Vector{Any}:
#  Dict{String, Any}("prediction_type" => "multi_step", "testing_params" => Dict{String, Any}("stochastic" => false, "mask_states_b4_readout" => false, "stochastic_rescale_V_rec" => false), "data" => "Lorenz 0_01", "num_partitions" => 1, "error_funcs" => Any["RMSE", "turning_partition_RMSE"], "testing_parameter" => "total_k", "k" => Any[156, 312, 624, 1248], "date" => "2025-03-09", "ignore_first" => 100, "errors" => Dict{String, Any}("RMSE" => Any[0.4978335126804165, 0.504831144759729], "turning_partition_RMSE" => Any[0.11816705861434669, 0.11797218150752495])…)
#  Dict{String, Any}("prediction_type" => "multi_step", "testing_params" => Dict{String, Any}("stochastic" => false, "mask_states_b4_readout" => false, "stochastic_rescale_V_rec" => false), "data" => "Lorenz 0_01", "num_partitions" => 1, "error_funcs" => Any["RMSE", "turning_partition_RMSE"], "testing_parameter" => "total_k", "k" => Any[156, 312, 624, 1248], "date" => "2025-03-09", "ignore_first" => 100, "errors" => Dict{String, Any}("RMSE" => Any[0.49829029701796207, 0.5062887166585895, 0.4817280291887994, 0.4711482337974513], "turning_partition_RMSE" => Any[0.11785956497368959, 0.11721255238267811, 0.11831247762904708, 0.11869430497878428])…)
#  Dict{String, Any}("prediction_type" => "multi_step", "testing_params" => Dict{String, Any}("stochastic" => false, "mask_states_b4_readout" => false, "stochastic_rescale_V_rec" => false), "data" => "Lorenz 0_01", "num_partitions" => 2, "error_funcs" => Any["RMSE", "turning_partition_RMSE"], "testing_parameter" => "total_k", "k" => Any[78, 156, 312, 624], "date" => "2025-03-09", "ignore_first" => 100, "errors" => Dict{String, Any}("RMSE" => Any[0.3869673854215416, 0.4289761930639608, 0.4441548644714927, 0.4500736853983996], "turning_partition_RMSE" => Any[0.1382322351274215, 0.12778550836787858, 0.12469687124365943, 0.1230914581736621])…)
#  Dict{String, Any}("prediction_type" => "multi_step", "testing_params" => Dict{String, Any}("stochastic" => false, "mask_states_b4_readout" => false, "stochastic_rescale_V_rec" => false), "data" => "Lorenz 0_01", "num_partitions" => 6, "error_funcs" => Any["RMSE", "turning_partition_RMSE"], "testing_parameter" => "total_k", "k" => Any[26, 52, 104, 208], "date" => "2025-03-09", "ignore_first" => 100, "errors" => Dict{String, Any}("RMSE" => Any[0.6670459735243782, 0.6251782962210414, 0.7023847611941726, 0.7340176644068986], "turning_partition_RMSE" => Any[2.883088840913539, 2.5539588102691724, 2.864517568131578, 2.938118234285717])…)
#  Dict{String, Any}("prediction_type" => "multi_step", "testing_params" => Dict{String, Any}("stochastic" => false, "mask_states_b4_readout" => false, "stochastic_rescale_V_rec" => false), "data" => "Lorenz 0_01", "num_partitions" => 13, "error_funcs" => Any["RMSE", "turning_partition_RMSE"], "testing_parameter" => "total_k", "k" => Any[12, 24, 48, 96], "date" => "2025-03-10", "ignore_first" => 100, "errors" => Dict{String, Any}("RMSE" => Any[1.3752168117866155, 1.6304427954195473, 1.8605742437433557, 2.0190494563089305], "turning_partition_RMSE" => Any[4.748756440923392, 5.9507289859262045, 6.936829601965042, 7.773474480435])…)

# %%
test_dict = Dict()

for test in ON_layered_tests
    m_value = "m = " * string(test["m"])
    test_dict[m_value] = test
end

# %%
chart_tests(
    "RMSE vs k_total",
    "k_total",
    "RMSE",
    test_dict,
    metrics=["RMSE"]
)

# %%
chart_tests(
    "Turning Partition RMSE vs k_total",
    "k",
    "Turning Partition RMSE",
    test_dict,
    metrics=["turning_partition_RMSE"]
)

# %% [markdown]
# ## Number of steps = 5

# %%
ON_layered_test_search = Dict(
    "prediction_type" => "multi_step",
    "testing_params" => Dict(
        "mask_states_b4_readout" => false,
        "stochastic" => false,
        "stochastic_rescale_V_rec" => false
    ),
    "data" => "Lorenz 0_01",
    "testing_parameter" => "k",
    "ignore_first" => 100,
    "n_steps" => 5,
    "trials" => 30
)
ON_layered_tests = find_test(ON_layered_test_search)

for test in ON_layered_tests
    test["total_k"] = test["k"]*test["num_partitions"]
    test["testing_parameter"] = "total_k"
    println(test["total_k"])
end

ON_layered_tests
# Out:
# [156, 312, 624, 1248]
# [156, 312, 624, 1248]
# [156, 312, 624, 1248]
# [156, 312, 624, 1248]
# [156, 312, 624, 1248]
# 5-element Vector{Any}:
#  Dict{String, Any}("prediction_type" => "multi_step", "testing_params" => Dict{String, Any}("stochastic" => false, "mask_states_b4_readout" => false, "stochastic_rescale_V_rec" => false), "data" => "Lorenz 0_01", "num_partitions" => 1, "error_funcs" => Any["RMSE", "turning_partition_RMSE"], "testing_parameter" => "total_k", "k" => Any[156, 312, 624, 1248], "date" => "2025-03-09", "ignore_first" => 100, "errors" => Dict{String, Any}("RMSE" => Any[1.6410749010742298, 1.6953602172635642, 1.5801089259702867, 1.5291582186280113], "turning_partition_RMSE" => Any[1.0283194025366533, 1.061589960062681, 1.0429451221303887, 1.0450052293376901])…)
#  Dict{String, Any}("prediction_type" => "multi_step", "testing_params" => Dict{String, Any}("stochastic" => false, "mask_states_b4_readout" => false, "stochastic_rescale_V_rec" => false), "data" => "Lorenz 0_01", "num_partitions" => 1, "error_funcs" => Any["RMSE", "turning_partition_RMSE"], "testing_parameter" => "total_k", "k" => Any[156, 312, 624, 1248], "date" => "2025-03-09", "ignore_first" => 100, "errors" => Dict{String, Any}("RMSE" => Any[1.618941307578187, 1.6725001085611482, 1.5806391257301144, 1.5066586204121761], "turning_partition_RMSE" => Any[1.024481216495539, 1.061402504027792, 1.048790281726486, 1.0537283482252475])…)
#  Dict{String, Any}("prediction_type" => "multi_step", "testing_params" => Dict{String, Any}("stochastic" => false, "mask_states_b4_readout" => false, "stochastic_rescale_V_rec" => false), "data" => "Lorenz 0_01", "num_partitions" => 2, "error_funcs" => Any["RMSE", "turning_partition_RMSE"], "testing_parameter" => "total_k", "k" => Any[78, 156, 312, 624], "date" => "2025-03-09", "ignore_first" => 100, "errors" => Dict{String, Any}("RMSE" => Any[1.1593141270359986, 1.4153119133460281, 1.5092175567120223, 1.4975670353690766], "turning_partition_RMSE" => Any[0.8851108195143016, 0.9523793701494674, 1.004155283858625, 1.0271874637306722])…)
#  Dict{String, Any}("prediction_type" => "multi_step", "testing_params" => Dict{String, Any}("stochastic" => false, "mask_states_b4_readout" => false, "stochastic_rescale_V_rec" => false), "data" => "Lorenz 0_01", "num_partitions" => 6, "error_funcs" => Any["RMSE", "turning_partition_RMSE"], "testing_parameter" => "total_k", "k" => Any[26, 52, 104, 208], "date" => "2025-03-10", "ignore_first" => 100, "errors" => Dict{String, Any}("RMSE" => Any[1.7594529297179353, 1.3846125281604318, 1.3973356558420613, 1.5495864448844954], "turning_partition_RMSE" => Any[1.4402197121828626, 1.3360612837220822, 1.400035075955166, 1.5277400558095657])…)
#  Dict{String, Any}("prediction_type" => "multi_step", "testing_params" => Dict{String, Any}("stochastic" => false, "mask_states_b4_readout" => false, "stochastic_rescale_V_rec" => false), "data" => "Lorenz 0_01", "num_partitions" => 13, "error_funcs" => Any["RMSE", "turning_partition_RMSE"], "testing_parameter" => "total_k", "k" => Any[12, 24, 48, 96], "date" => "2025-03-10", "ignore_first" => 100, "errors" => Dict{String, Any}("RMSE" => Any[53.15263962390696, 48.51161176404351, 50.578599443161096, 69.27584927651445], "turning_partition_RMSE" => Any[113.75446536318817, 108.91528384742922, 126.64471161426101, 153.5000632223832])…)

# %%
test_dict = Dict()

for test in ON_layered_tests
    m_value = "m = " * string(test["m"])
    test_dict[m_value] = test
end

# %%
chart_tests(
    "RMSE vs k_total",
    "k_total",
    "RMSE",
    test_dict,
    metrics=["RMSE"],
    ylim_low = 0,
    ylim_high=2
)

# %%
chart_tests(
    "Turning Partition RMSE vs k_total",
    "k",
    "Turning Partition RMSE",
    test_dict,
    metrics=["turning_partition_RMSE"],
    ylim_low = 0,
    ylim_high=2
)

# %% [markdown]
# ## Number of steps = 50

# %%
ON_layered_test_search = Dict(
    "prediction_type" => "multi_step",
    "testing_params" => Dict(
        "mask_states_b4_readout" => false,
        "stochastic" => false,
        "stochastic_rescale_V_rec" => false
    ),
    "data" => "Lorenz 0_01",
    "testing_parameter" => "k",
    "ignore_first" => 100,
    "n_steps" => 50,
    "trials" => 30
)
ON_layered_tests = find_test(ON_layered_test_search)

for test in ON_layered_tests
    test["total_k"] = test["k"]*test["num_partitions"]
    test["testing_parameter"] = "total_k"
    println(test["total_k"])
end

ON_layered_tests
# Out:
# [156, 312, 624, 1248]
# [156, 312, 624, 1248]
# [156, 312, 624, 1248]
# [156, 312, 624, 1248]
# [156, 312, 624, 1248]
# 5-element Vector{Any}:
#  Dict{String, Any}("prediction_type" => "multi_step", "testing_params" => Dict{String, Any}("stochastic" => false, "mask_states_b4_readout" => false, "stochastic_rescale_V_rec" => false), "data" => "Lorenz 0_01", "num_partitions" => 1, "error_funcs" => Any["RMSE", "turning_partition_RMSE"], "testing_parameter" => "total_k", "k" => Any[156, 312, 624, 1248], "date" => "2025-03-09", "ignore_first" => 100, "errors" => Dict{String, Any}("RMSE" => Any[6.967858025912297, 6.735468368060726, 6.523495394500478, 6.291606177489479], "turning_partition_RMSE" => Any[7.298627698051406, 6.980492590595244, 6.3718938896273345, 5.965920235807313])…)
#  Dict{String, Any}("prediction_type" => "multi_step", "testing_params" => Dict{String, Any}("stochastic" => false, "mask_states_b4_readout" => false, "stochastic_rescale_V_rec" => false), "data" => "Lorenz 0_01", "num_partitions" => 1, "error_funcs" => Any["RMSE", "turning_partition_RMSE"], "testing_parameter" => "total_k", "k" => Any[156, 312, 624, 1248], "date" => "2025-03-09", "ignore_first" => 100, "errors" => Dict{String, Any}("RMSE" => Any[6.882364256048258, 6.948590469767299, 6.595627545422594, 6.439610727440538], "turning_partition_RMSE" => Any[7.161375311362345, 7.282918141525146, 6.571900900296166, 6.234964318333116])…)
#  Dict{String, Any}("prediction_type" => "multi_step", "testing_params" => Dict{String, Any}("stochastic" => false, "mask_states_b4_readout" => false, "stochastic_rescale_V_rec" => false), "data" => "Lorenz 0_01", "num_partitions" => 2, "error_funcs" => Any["RMSE", "turning_partition_RMSE"], "testing_parameter" => "total_k", "k" => Any[78, 156, 312, 624], "date" => "2025-03-09", "ignore_first" => 100, "errors" => Dict{String, Any}("RMSE" => Any[5.570947032468254, 5.865803248017731, 5.928047366044438, 5.837231761573859], "turning_partition_RMSE" => Any[4.510740458841891, 5.127069452480555, 5.27989599796509, 5.15480923377795])…)
#  Dict{String, Any}("prediction_type" => "multi_step", "testing_params" => Dict{String, Any}("stochastic" => false, "mask_states_b4_readout" => false, "stochastic_rescale_V_rec" => false), "data" => "Lorenz 0_01", "num_partitions" => 6, "error_funcs" => Any["RMSE", "turning_partition_RMSE"], "testing_parameter" => "total_k", "k" => Any[26, 52, 104, 208], "date" => "2025-03-10", "ignore_first" => 100, "errors" => Dict{String, Any}("RMSE" => Any[7.033693814688777, 5.4232434324653065, 5.830476609053343, 6.2788190677380715], "turning_partition_RMSE" => Any[6.340571608522965, 4.425338645749039, 5.066423993871358, 5.8739669523635305])…)
#  Dict{String, Any}("prediction_type" => "multi_step", "testing_params" => Dict{String, Any}("stochastic" => false, "mask_states_b4_readout" => false, "stochastic_rescale_V_rec" => false), "data" => "Lorenz 0_01", "num_partitions" => 13, "error_funcs" => Any["RMSE", "turning_partition_RMSE"], "testing_parameter" => "total_k", "k" => Any[12, 24, 48, 96], "date" => "2025-03-10", "ignore_first" => 100, "errors" => Dict{String, Any}("RMSE" => Any[185.6832727920813, 153.4173181705604, 174.57838287108072, 193.2986049045789], "turning_partition_RMSE" => Any[195.42678431479723, 156.86773957418782, 178.6629416323682, 201.76530367807132])…)

# %%
test_dict = Dict()

for test in ON_layered_tests
    m_value = "m = " * string(test["m"])
    test_dict[m_value] = test
end

# %%
chart_tests(
    "RMSE vs k_total",
    "k_total",
    "RMSE",
    test_dict,
    metrics=["RMSE"],
    ylim_low = 0,
    ylim_high=8
)

# %%
chart_tests(
    "Turning Partition RMSE vs k_total",
    "k",
    "Turning Partition RMSE",
    test_dict,
    metrics=["turning_partition_RMSE"],
    ylim_low = 0,
    ylim_high=8
)

# %% [markdown]
# # Other tests

# %% [markdown]
# ## m = 3, k = 50

# %%
ON_layered_test_search = Dict(
    "prediction_type" => "multi_step",
    "testing_params" => Dict(
        "mask_states_b4_readout" => false,
        "stochastic" => false,
        "stochastic_rescale_V_rec" => false
    ),
    "data" => "Lorenz 0_01",
    "testing_parameter" => "n_steps",
    "k" => 50,
    "ignore_first" => 100,
    "m" => 3,
    "trials" => 30
)
ON_layered_tests = find_test(ON_layered_test_search)[1];

vanilla_test_search = copy(ON_layered_test_search)
vanilla_test_search["m"] = 1
vanilla_test_search["k"] = 300
vanilla_test = find_test(vanilla_test_search)[1];

test_dict = Dict(
    "Vanilla ESN" => vanilla_test,
    "ON Layered ESN" => ON_layered_test
)

chart_tests(
    "RMSE vs number of prediction steps",
    "Number of prediction steps",
    "RMSE",
    test_dict
)

# %%
ON_layered_turning_test_search = copy(ON_layered_test_search)
ON_layered_turning_test_search["error_func"] = "turning_partition_RMSE"
ON_layered_turning_test = find_test(ON_layered_turning_test_search)[1];

vanilla_turning_test_search = copy(ON_layered_turning_test_search)
vanilla_turning_test_search["m"] = 1
vanilla_turning_test_search["k"] = 300
vanilla_turning_test = find_test(vanilla_turning_test_search)[1];

chart_tests(
    "Turning RMSE vs number of prediction steps",
    "Number of prediction steps",
    "Turning RMSE",
    Dict(
        "Vanilla ESN" => vanilla_turning_test,
        "ON Layered ESN" => ON_layered_turning_test
    )
)
# Out:
# No matching test found
#
#
#
# Stacktrace:
#
#  [1] error(s::String)
#
#    @ Base ./error.jl:35
#
#  [2] find_test(test_dict::Dict{String, Any})
#
#    @ Main.TestingFunctions ~/Desktop/Uni/Honours Research/echo-state-networks/Modules/TestingFunctions.jl:511
#
#  [3] top-level scope
#
#    @ ~/Desktop/Uni/Honours Research/echo-state-networks/Notebooks/ON_layered - hyperparameters/jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_W4sZmlsZQ==.jl:2

# %% [markdown]
# ## m = 3, k = 100

# %%
ON_layered_test_search["k"] = 100
ON_layered_test = find_test(ON_layered_test_search)[1];

vanilla_test_search["k"] = 600
vanilla_test = find_test(vanilla_test_search)[1];

chart_tests(
    "RMSE vs number of prediction steps",
    "Number of prediction steps",
    "RMSE",
    Dict(
        "Vanilla ESN" => vanilla_test,
        "ON Layered ESN" => ON_layered_test
    )
)

# %%
ON_layered_turning_test_search["k"] = 100
ON_layered_turning_test = find_test(ON_layered_turning_test_search)[1];

vanilla_turning_test_search["k"] = 600
vanilla_turning_test = find_test(vanilla_turning_test_search)[1];

chart_tests(
    "Turning RMSE vs number of prediction steps",
    "Number of prediction steps",
    "Turning RMSE",
    Dict(
        "Vanilla ESN" => vanilla_turning_test,
        "ON Layered ESN" => ON_layered_turning_test
    )
)
# Out:
# No matching test found
#
#
#
# Stacktrace:
#
#  [1] error(s::String)
#
#    @ Base ./error.jl:35
#
#  [2] find_test(test_dict::Dict{String, Any})
#
#    @ Main.TestingFunctions ~/Desktop/Uni/Honours Research/echo-state-networks/Modules/TestingFunctions.jl:511
#
#  [3] top-level scope
#
#    @ ~/Desktop/Uni/Honours Research/echo-state-networks/Notebooks/ON_layered - hyperparameters/jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X10sZmlsZQ==.jl:1

# %% [markdown]
# ## m = 4, k = 50

# %%
ON_layered_test_search = Dict(
    "prediction_type" => "multi_step",
    "testing_params" => Dict(
        "mask_states_b4_readout" => false,
        "stochastic" => false,
        "stochastic_rescale_V_rec" => false
    ),
    "data" => "Lorenz 0_01",
    "testing_parameter" => "n_steps",
    "k" => 50,
    "ignore_first" => 100,
    "m" => 4,
    "trials" => 30
)
ON_layered_test = find_test(ON_layered_test_search)[1];

vanilla_test_search = copy(ON_layered_test_search)
vanilla_test_search["m"] = 1
vanilla_test_search["k"] = 650
vanilla_test = find_test(vanilla_test_search)[1];

chart_tests(
    "RMSE vs number of prediction steps",
    "Number of prediction steps",
    "RMSE",
    Dict(
        "Vanilla ESN" => vanilla_test,
        "ON Layered ESN" => ON_layered_test
    )
)

# %%
ON_layered_turning_test_search = copy(ON_layered_test_search)
ON_layered_turning_test_search["error_func"] = "turning_partition_RMSE"
ON_layered_turning_test = find_test(ON_layered_turning_test_search)[1];

vanilla_turning_test_search = copy(vanilla_test_search)
vanilla_turning_test_search["error_func"] = "turning_partition_RMSE"
vanilla_turning_test = find_test(vanilla_turning_test_search)[1];

chart_tests(
    "Turning RMSE vs number of prediction steps",
    "Number of prediction steps",
    "Turning RMSE",
    Dict(
        "Vanilla ESN" => vanilla_turning_test,
        "ON Layered ESN" => ON_layered_turning_test
    )
)
# Out:
# No matching test found
#
#
#
# Stacktrace:
#
#  [1] error(s::String)
#
#    @ Base ./error.jl:35
#
#  [2] find_test(test_dict::Dict{String, Any})
#
#    @ Main.TestingFunctions ~/Desktop/Uni/Honours Research/echo-state-networks/Modules/TestingFunctions.jl:511
#
#  [3] top-level scope
#
#    @ ~/Desktop/Uni/Honours Research/echo-state-networks/Notebooks/ON_layered - hyperparameters/jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X13sZmlsZQ==.jl:2

# %%
ON_layered_test
# Out:
# Dict{String, Any} with 14 entries:
#   "prediction_type"   => "multi_step"
#   "testing_params"    => Dict{String, Any}("stochastic"=>false, "mask_states_b4…
#   "data"              => "Lorenz 0_01"
#   "num_partitions"    => 13
#   "error_funcs"       => Any["turning_partition_RMSE", "RMSE"]
#   "testing_parameter" => "n_steps"
#   "k"                 => 50
#   "date"              => "2025-03-08"
#   "ignore_first"      => 100
#   "errors"            => Dict{String, Any}("RMSE"=>Any[1.85339, 35.9369, 37.991…
#   "m"                 => 4
#   "trials"            => 30
#   "total_k"           => 650
#   "n_steps"           => Any[1, 2, 3, 5, 10, 20, 30, 40, 50, 70, 100]

# %% [markdown]
# ## m = 4, k = 100

# %%
ON_layered_test_search = Dict(
    "prediction_type" => "multi_step",
    "testing_params" => Dict(
        "mask_states_b4_readout" => false,
        "stochastic" => false,
        "stochastic_rescale_V_rec" => false
    ),
    "data" => "Lorenz 0_01",
    "testing_parameter" => "n_steps",
    "k" => 100,
    "ignore_first" => 100,
    "m" => 4,
    "trials" => 30
)
ON_layered_test = find_test(ON_layered_test_search)[1];

vanilla_test_search = copy(ON_layered_test_search)
vanilla_test_search["m"] = 1
vanilla_test_search["k"] = 1300
vanilla_test = find_test(vanilla_test_search)[1];

chart_tests(
    "RMSE vs number of prediction steps",
    "Number of prediction steps",
    "RMSE",
    Dict(
        "Vanilla ESN" => vanilla_test,
        "ON Layered ESN" => ON_layered_test
    )
)

# %%
ON_layered_turning_test_search = copy(ON_layered_test_search)
ON_layered_turning_test_search["error_func"] = "turning_partition_RMSE"
ON_layered_turning_test = find_test(ON_layered_turning_test_search)[1];

vanilla_turning_test_search = copy(vanilla_test_search)
vanilla_turning_test_search["error_func"] = "turning_partition_RMSE"
vanilla_turning_test = find_test(vanilla_turning_test_search)[1];

chart_tests(
    "Turning RMSE vs number of prediction steps",
    "Number of prediction steps",
    "Turning RMSE",
    Dict(
        "Vanilla ESN" => vanilla_turning_test,
        "ON Layered ESN" => ON_layered_turning_test
    )
)
# Out:
# No matching test found
#
#
#
# Stacktrace:
#
#  [1] error(s::String)
#
#    @ Base ./error.jl:35
#
#  [2] find_test(test_dict::Dict{String, Any})
#
#    @ Main.TestingFunctions ~/Desktop/Uni/Honours Research/echo-state-networks/Modules/TestingFunctions.jl:511
#
#  [3] top-level scope
#
#    @ ~/Desktop/Uni/Honours Research/echo-state-networks/Notebooks/ON_layered - hyperparameters/jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X20sZmlsZQ==.jl:2
